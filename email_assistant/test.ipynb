# %%
prompt_template = """
You are an agent designed to interact with a SQL database.
Given an input question, create a syntactically correct {dialect} query to run, then look at the results of the query and return the answer.
Unless the user specifies a specific number of examples they wish to obtain, always limit your query to at most {top_k} results.
You can order the results by a relevant column to return the most interesting examples in the database.
Never query for all the columns from a specific table, only ask for the relevant columns given the question.
You have access to tools for interacting with the database.
Only use the below tools. Only use the information returned by the below tools to construct your final answer.
You MUST double check your query before executing it. If you get an error while executing a query, rewrite the query and try again.

DO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the database.

To start you should ALWAYS look at the tables in the database to see what you can query.
Do NOT skip this step.
Then you should query the schema of the most relevant tables.
"""

system_message = prompt_template.format(dialect="SQLite", top_k=5)

# %%
from langchain_community.utilities.sql_database import SQLDatabase
from sqlalchemy import create_engine


engine = create_engine(
    "mysql+pymysql://NEXXBot:WaaS_2024@annexx.ctsues4qm1zh.ap-east-1.rds.amazonaws.com:3306/olist"
)

db = SQLDatabase(engine)

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model("azure_openai:gpt-4o", temperature=0.0)

# %%
from langchain_community.agent_toolkits.sql.toolkit import SQLDatabaseToolkit

toolkit = SQLDatabaseToolkit(db=db, llm=llm)

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=llm,
    tools=toolkit.get_tools(),
    system_prompt=system_message,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 5
#       1 from langchain.agents import create_agent
#       3 agent = create_agent(
#       4     model=llm,
# ----> 5     tools=toolkit.get_tools(),
#       6     system_prompt=system_message,
#       7 )
#
# File d:\GitHub\Me\langchain\office365\.venv\Lib\site-packages\langchain_community\agent_toolkits\sql\toolkit.py:124, in SQLDatabaseToolkit.get_tools(self)
#     116 query_sql_database_tool = QuerySQLDatabaseTool(
#     117     db=self.db, description=query_sql_database_tool_description
#     118 )
#     119 query_sql_checker_tool_description = (
#     120     "Use this tool to double check if your query is correct before executing "
#     121     "it. Always use this tool before executing a query with "
#     122     f"{query_sql_database_tool.name}!"
#     123 )
# --> 124 query_sql_checker_tool = QuerySQLCheckerTool(
#     125     db=self.db, llm=self.llm, description=query_sql_checker_tool_description
#     126 )
#     127 return [
#     128     query_sql_database_tool,
#     129     info_sql_database_tool,
#     130     list_sql_database_tool,
#     131     query_sql_checker_tool,
#     132 ]
#
# File d:\GitHub\Me\langchain\office365\.venv\Lib\site-packages\langchain_core\tools\base.py:508, in BaseTool.__init__(self, **kwargs)
#     503     msg = (
#     504         "args_schema must be a subclass of pydantic BaseModel or "
#     505         f"a JSON schema dict. Got: {kwargs['args_schema']}."
#     506     )
#     507     raise TypeError(msg)
# --> 508 super().__init__(**kwargs)
#
# File d:\GitHub\Me\langchain\office365\.venv\Lib\site-packages\langchain_core\load\serializable.py:113, in Serializable.__init__(self, *args, **kwargs)
#     111 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     112     """"""  # noqa: D419  # Intentional blank docstring
# --> 113     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\GitHub\Me\langchain\office365\.venv\Lib\site-packages\langchain_community\tools\sql_database\tool.py:145, in QuerySQLCheckerTool.initialize_llm_chain(cls, values)
#     141 @model_validator(mode="before")
#     142 @classmethod
#     143 def initialize_llm_chain(cls, values: Dict[str, Any]) -> Any:
#     144     if "llm_chain" not in values:
# --> 145         from langchain.chains.llm import LLMChain
#     147         values["llm_chain"] = LLMChain(
#     148             llm=values.get("llm"),  # type: ignore[arg-type]
#     149             prompt=PromptTemplate(
#     150                 template=QUERY_CHECKER, input_variables=["dialect", "query"]
#     151             ),
#     152         )
#     154     if values["llm_chain"].prompt.input_variables != ["dialect", "query"]:
#
# ModuleNotFoundError: No module named 'langchain.chains'
